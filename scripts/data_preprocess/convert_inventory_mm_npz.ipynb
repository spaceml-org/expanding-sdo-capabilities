# %% [markdown]
# Script that will convert from the old MM path to the NPZ path on GCP buckets. Note that the inventory file we write out is compressed as a GZIP file.

# %%
#export GOOGLE_APPLICATION_CREDENTIALS=/home/bradneuberg/expanding-sdo-capabilities/config/space_weather_sdo.json

# %%
from io import BytesIO

from google.cloud import storage
from google.cloud.storage.blob import Blob
import pandas as pd

# %%
bucket_name = 'fdl-sdo-data'
inventory_in_path = 'SDOMLmm/inventory.pkl'

client = storage.Client()
bucket = client.get_bucket(bucket_name)

data = bucket.blob(inventory_in_path).download_as_string()

# %%
df = pd.read_pickle(BytesIO(data), compression=None)

# %%
df
# Out:
#             year  month  day  hour  min channel  \
# index
# 1076941452  2010      5    1     0   12      by
# 1076941452  2010      5    1     0   12      bx
# 1076941452  2010      5    1     0   12      bz
# 1076941464  2010      5    1     0   24      by
# 1076941464  2010      5    1     0   24      bx
# ...          ...    ...  ...   ...  ...     ...
# 1081552314  2018     12    9    23   54    1600
# 1081552314  2018     12    9    23   54    1700
# 1081552314  2018     12    9    23   54    0094
# 1081552314  2018     12    9    23   54    0193
# 1081552314  2018     12    9    23   54    0171
#
#                                                          file
# index
# 1076941452  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941452  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941452  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941464  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941464  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# ...                                                       ...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
#
# [7345140 rows x 7 columns]

# %%
in_path = '/fdl_sdo_data/SDOMLmm/'
out_path = 'SDOMLnpz/'

# %%
df.replace({in_path: out_path}, regex=True, inplace=True)

# %%
df
# Out:
#             year  month  day  hour  min channel  \
# index
# 1076941452  2010      5    1     0   12      by
# 1076941452  2010      5    1     0   12      bx
# 1076941452  2010      5    1     0   12      bz
# 1076941464  2010      5    1     0   24      by
# 1076941464  2010      5    1     0   24      bx
# ...          ...    ...  ...   ...  ...     ...
# 1081552314  2018     12    9    23   54    1600
# 1081552314  2018     12    9    23   54    1700
# 1081552314  2018     12    9    23   54    0094
# 1081552314  2018     12    9    23   54    0193
# 1081552314  2018     12    9    23   54    0171
#
#                                                     file
# index
# 1076941452    SDOMLnpz/2010/05/01/HMI20100501_0012_by.mm
# 1076941452    SDOMLnpz/2010/05/01/HMI20100501_0012_bx.mm
# 1076941452    SDOMLnpz/2010/05/01/HMI20100501_0012_bz.mm
# 1076941464    SDOMLnpz/2010/05/01/HMI20100501_0024_by.mm
# 1076941464    SDOMLnpz/2010/05/01/HMI20100501_0024_bx.mm
# ...                                                  ...
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_1600.mm
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_1700.mm
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_0094.mm
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_0193.mm
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_0171.mm
#
# [7345140 rows x 7 columns]

# %%
local_path = '/tmp/inventory.pkl'
df.to_pickle(local_path, compression='gzip')

# %%
inventory_out_path = 'SDOMLnpz/inventory.pkl'
blob = Blob(inventory_out_path, bucket)
blob.upload_from_filename(local_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d555208322db> in <module>
#       1 inventory_out_path = 'SDOMLnpz/inventory.pkl'
#       2 blob = Blob(inventory_out_path, bucket)
# ----> 3 out_buf.seek(0)
#       4 blob.upload_from_file(out_buf)
#
# ValueError: I/O operation on closed file.
