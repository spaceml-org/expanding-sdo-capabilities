# %% [markdown]
# Script that will convert from the old MM path to the NPZ path on GCP buckets. Note that the inventory file we write out is compressed as a GZIP file.

# %%
# Make sure to define the following environment variable before you run this:
#export GOOGLE_APPLICATION_CREDENTIALS=~/expanding-sdo-capabilities/config/space_weather_sdo.json
# And also run the following command to allow GCP storage access:
# gcloud auth application-default login

# %%
from io import BytesIO

from google.cloud import storage
from google.cloud.storage.blob import Blob
import pandas as pd

# %%
bucket_name = 'fdl-sdo-data'
inventory_in_path = 'SDOMLmm/inventory.pkl'

client = storage.Client()
bucket = client.get_bucket(bucket_name)

# %%
data = bucket.blob(inventory_in_path).download_as_string()

# %%
df = pd.read_pickle(BytesIO(data), compression=None)

# %%
df
# Out:
#             year  month  day  hour  min channel  \
# index
# 1076941452  2010      5    1     0   12      by
# 1076941452  2010      5    1     0   12      bx
# 1076941452  2010      5    1     0   12      bz
# 1076941464  2010      5    1     0   24      by
# 1076941464  2010      5    1     0   24      bx
# ...          ...    ...  ...   ...  ...     ...
# 1081552314  2018     12    9    23   54    1600
# 1081552314  2018     12    9    23   54    1700
# 1081552314  2018     12    9    23   54    0094
# 1081552314  2018     12    9    23   54    0193
# 1081552314  2018     12    9    23   54    0171
#
#                                                          file
# index
# 1076941452  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941452  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941452  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941464  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# 1076941464  /fdl_sdo_data/SDOMLmm/2010/05/01/HMI20100501_0...
# ...                                                       ...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
# 1081552314  /fdl_sdo_data/SDOMLmm/2018/12/09/AIA20181209_2...
#
# [7345140 rows x 7 columns]

# %%
df.replace({
    '/fdl_sdo_data/SDOMLmm/': 'SDOMLnpz/',
    '.mm': '.npz',
}, regex=True, inplace=True)

# %%
df
# Out:
#             year  month  day  hour  min channel  \
# index
# 1076941452  2010      5    1     0   12      by
# 1076941452  2010      5    1     0   12      bx
# 1076941452  2010      5    1     0   12      bz
# 1076941464  2010      5    1     0   24      by
# 1076941464  2010      5    1     0   24      bx
# ...          ...    ...  ...   ...  ...     ...
# 1081552314  2018     12    9    23   54    1600
# 1081552314  2018     12    9    23   54    1700
# 1081552314  2018     12    9    23   54    0094
# 1081552314  2018     12    9    23   54    0193
# 1081552314  2018     12    9    23   54    0171
#
#                                                      file
# index
# 1076941452    SDOMLnpz/2010/05/01/HMI20100501_0012_by.npz
# 1076941452    SDOMLnpz/2010/05/01/HMI20100501_0012_bx.npz
# 1076941452    SDOMLnpz/2010/05/01/HMI20100501_0012_bz.npz
# 1076941464    SDOMLnpz/2010/05/01/HMI20100501_0024_by.npz
# 1076941464    SDOMLnpz/2010/05/01/HMI20100501_0024_bx.npz
# ...                                                   ...
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_1600.npz
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_1700.npz
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_0094.npz
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_0193.npz
# 1081552314  SDOMLnpz/2018/12/09/AIA20181209_2354_0171.npz
#
# [7345140 rows x 7 columns]

# %%
local_path = '/tmp/inventory.pkl'
df.to_pickle(local_path, compression='gzip')

# %%
# Note: you will get permission errors if this file already exists on GCP;
# if this happens, simply navigate to the existing SDOMLnpz/inventory.pkl file
# and delete it in the GCP browser before attempting to re-upload a new version.
inventory_out_path = 'SDOMLnpz/inventory.pkl'
blob = Blob(inventory_out_path, bucket)
blob.upload_from_filename(local_path)
