# %% [markdown]
# Quick example of how to load saved alpha

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Auto calibration results

# %%
file = '/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/experiments_results/01v_experiment_test/0004_01v_experiment_test_test_predictions.npy'

# %%
dim_factors = np.load(file)

# %%
dim_factors.shape
# Out:
# (691, 7, 2)

# %%
alpha_gt = dim_factors[:,:,0]

# %%
alpha_pred = dim_factors[:,:,1]

# %%
abs(alpha_gt - alpha_pred).mean()
# Out:
# 0.14840502

# %% [markdown]
# ## Virtual telescope results

# %%
file = '/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/experiments_results_vt/v_experiment_5/2000_v_experiment_5_test_predictions.npy'

# %%
predictions = np.load(file)

# %%
predictions.shape
# len_dataset, batch_size
# Out:
# (1724, 1, 256, 128)

# %%
img = predictions[10,0,0:128,:]
plt.imshow(img, cmap='magma', vmax=3, origin='lower')

# %%
predicted_img = predictions[10,0,128:,:]
plt.imshow(img, cmap='magma', vmax=3, origin='lower')
