# %% [markdown]
# Mark has prepared a table that, for each existing timestamp and channel combination, report the file path. In this notebook we try to load it and see how to integrate it in the data loader. The file is time ordered in ascending order, the first available date is 2010/05/01. We also plot some distributions of the dataset to understand if there are gaps, irregularities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
inventory_path = '/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/inventory.pkl'

# %%
df=pd.read_pickle("/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/inventory.pkl")

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# 2017    734263
# 2018    729070
# 2013    721980
# 2015    721132
# 2011    714670
# 2016    710407
# 2014    707106
# 2012    702938
# 2010    391918
# Name: year, dtype: int64
# 10    661898
# 7     660718
# 6     645203
# 8     641080
# 5     637133
# 9     612326
# 1     597908
# 3     570120
# 4     567224
# 2     539874
# Name: month, dtype: int64
# 21    207613
# 15    207104
# 22    205866
# 25    204592
# 17    204457
# 19    204162
# 14    203990
# 7     203898
# 11    203769
# 27    203438
# 2     202768
# 24    202718
# 18    202695
# 16    202635
# 12    201642
# 10    201346
# 28    200397
# 1     199525
# 5     199339
# 13    198879
# 3     198854
# 26    198706
# 23    198181
# 20    197686
# 9     197592
# 8     197353
# 4     196428
# 6     194101
# 29    188151
# 30    183948
# 31    121651
# Name: day, dtype: int64
# 1     264302
# 3     264219
# 4     264108
# 2     263962
# 5     263749
# 0     263235
# 12    262864
# 11    262750
# 10    262741
# 23    261850
# 13    260325
# 22    259869
# 9     259778
# 14    258786
# 17    256169
# 16    255726
# 8     255706
# 19    253137
# 15    253026
# 20    251085
# 18    241488
# 21    238563
# 7     231056
# 6     224990
# Name: hour, dtype: int64
# 48    712055
# 36    711443
# 24    711297
# 12    699322
# 0     626466
# 54    535911
# 42    534816
# 18    534274
# 30    534024
# 6     533876
# Name: min, dtype: int64
# 1600    592544
# 0211    592202
# 0193    592071
# 0335    592045
# 0171    591782
# 0131    591537
# 0094    591237
# 0304    590156
# 1700    543895
# by      285343
# bx      285337
# bz      285335
# Name: channel, dtype: int64
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2016/07/23/AIA20160723_1218_0335.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2018/05/29/AIA20180529_1306_0193.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/06/22/HMI20110622_0348_bx.npz      1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2018/06/23/AIA20180623_0524_1700.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/04/24/AIA20110424_1200_0171.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2013/05/04/AIA20130504_1012_0211.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2017/04/16/AIA20170416_2236_0211.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2014/03/07/AIA20140307_2024_0335.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2017/03/24/AIA20170324_1354_0211.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2018/07/19/AIA20180719_2054_0171.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2016/06/09/AIA20160609_1742_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/09/26/AIA20120926_0924_0335.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2013/06/22/AIA20130622_0636_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/08/17/AIA20120817_1812_0171.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2014/08/13/AIA20140813_1006_0171.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2017/02/18/AIA20170218_1312_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2015/06/01/HMI20150601_1036_bx.npz      1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2016/07/07/AIA20160707_1448_0211.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/10/28/AIA20111028_2106_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/05/16/AIA20120516_1242_0094.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2014/10/07/AIA20141007_0812_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2016/06/25/AIA20160625_1348_1700.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/07/01/AIA20120701_0300_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/01/14/AIA20120114_0418_0094.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2018/08/07/AIA20180807_0430_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/03/11/AIA20110311_0100_1700.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/05/24/HMI20100524_0524_bx.npz      1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2015/08/01/AIA20150801_0918_1600.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/09/13/AIA20110913_1600_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2014/05/12/AIA20140512_2206_0171.npz    1
#                                                                                ..
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2015/08/27/HMI20150827_0112_bx.npz      1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/01/25/AIA20120125_0200_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/03/09/AIA20110309_0612_0193.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2014/06/07/AIA20140607_0400_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/05/30/AIA20120530_0618_0211.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2015/06/07/AIA20150607_1148_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2015/07/04/AIA20150704_1330_0094.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2015/01/07/AIA20150107_0648_1600.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2018/03/11/AIA20180311_1842_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/07/14/AIA20120714_1548_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2017/10/23/AIA20171023_1518_0094.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/07/29/HMI20100729_0100_bz.npz      1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/05/31/AIA20110531_2206_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2015/02/19/AIA20150219_2300_0193.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2013/09/01/AIA20130901_0530_0193.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/09/25/AIA20100925_0518_1600.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/06/26/AIA20120626_0124_0304.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2016/10/08/HMI20161008_0800_by.npz      1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2017/07/25/AIA20170725_0942_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2014/06/23/AIA20140623_0206_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/10/02/AIA20111002_1930_0193.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/08/12/AIA20110812_0606_1700.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/09/20/AIA20100920_1100_0171.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/07/06/AIA20110706_1018_0171.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2017/02/03/AIA20170203_1048_1600.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2013/06/04/AIA20130604_1636_0131.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2014/06/07/AIA20140607_0848_0094.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2016/01/13/HMI20160113_1312_bx.npz      1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2012/10/29/AIA20121029_0212_0193.npz    1
# /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2016/06/28/AIA20160628_2312_0094.npz    1
# Name: file, Length: 6133484, dtype: int64

# %%
bin_dict = dict(zip(['year','month', 'day', 'hour', 'min'], [9, 10, 31, 24, 10]))

# %%
# we have the double of the data in 2018 (incresead time resolution?)
# the other distributions are pretty flat
# expected trend for minutes, every 12min we have also the bx,by,bz data
i = 0
for col, bins in bin_dict.items():
    plt.figure()
    df[col].hist(label=col, bins=bins)
    if col == 'month':
        ticks = np.arange(1, 11)
    elif col == 'year':
         ticks = np.arange(2010, 2019)
    elif col == 'day':
         ticks = np.arange(1, 32)
    elif col == 'min':
         ticks = np.arange(0, 61, 6)
    else:
        ticks = np.arange(0, 25)        
    plt.xticks(ticks)
    plt.legend()
    i += 1

# %%
df.head()
# Out:
#             year  month  day  hour  min channel  \
# index
# 1076941452  2010      5    1     0   12      by
# 1076941452  2010      5    1     0   12      bz
# 1076941452  2010      5    1     0   12      bx
# 1076941464  2010      5    1     0   24      bz
# 1076941464  2010      5    1     0   24      by
#
#                                                          file
# index
# 1076941452  /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/0...
# 1076941452  /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/0...
# 1076941452  /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/0...
# 1076941464  /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/0...
# 1076941464  /gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2010/0...

# %%
# let's try to select on channels, years, months, days, hours and minutes
index = ['year', 'month', 'day', 'hour', 'min']
channels = ['0094','0131','0171','bx']
yrs = np.arange(2011, 2012)
months = np.arange(1,10,1)
days = np.arange(1,32,7)
hours = np.arange(0, 25, 12)
minus = np.arange(0, 61, 12)

# %%
cond0 = df['channel'].isin(channels)
cond1 = df['year'].isin(yrs)
cond2 = df['month'].isin(months)
cond3 = df['day'].isin(days)
cond4 = df['hour'].isin(hours)
cond5 = df['min'].isin(minus)
sel_df = df[cond0 & cond1 & cond2 & cond3 & cond4 & cond5]
sel_df.groupby(index).head(1).shape[0]
# Out:
# 440

# %%
grouped_df = sel_df.groupby(index).size()
# we select only timestamp that have files for all the channels
grouped_df = grouped_df[grouped_df == len(channels)].to_frame()
sel_df = sel_df.reset_index().drop('index', axis=1)
sel_df = pd.merge(grouped_df, sel_df, how='inner', left_on=index, right_on=index)

# %%
# sorting is essential, otherwise at each step the order of the channels will not be consistent
s_files = sel_df.sort_values('channel').groupby(index)['file'].apply(list)

# %%
results = tuple(zip(s_files,s_files.index))

# %%
tuple(zip(s_files.values.tolist(), s_files.index.tolist()))[0]
# Out:
# (['/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/01/01/AIA20110101_0000_0094.npz',
#   '/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/01/01/AIA20110101_0000_0131.npz',
#   '/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/01/01/AIA20110101_0000_0171.npz',
#   '/gpfs/gpfs_gl4_16mb/b9p111/fdl_sw/SDOML/2011/01/01/HMI20110101_0000_bx.npz'],
#  (2011, 1, 1, 0, 0))

# %%
len(s_files.index.tolist())
# Out:
# 422

# %% [markdown]
# Okay this seems a strategy that is quick enough, it will be applied in the sdo dataset, in replacement of the previous version.
