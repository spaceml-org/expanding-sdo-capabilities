# %% [markdown]
# # Error on the reconstructed covariance - possible way to predict solar flares?
#
# In this notebook we want to test on multiple flare events if it's true that the reconstruction error on the covariance starts to fail before the flare is visible.

# %%
# !pip install img2pdf --user
# Out:
# Collecting img2pdf
#   Downloading https://files.pythonhosted.org/packages/80/ed/5167992abaf268f5a5867e974d9d36a8fa4802800898ec711f4e1942b4f5/img2pdf-0.4.0.tar.gz (107kB)
#      |████████████████████████████████| 112kB 9.2MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.7/site-packages (from img2pdf) (6.1.0)
# Collecting pikepdf
#   Downloading https://files.pythonhosted.org/packages/44/85/31beda39cdd5ee50be35f218929fecfceb860a0a55eeb2081388a5957510/pikepdf-2.7.0-cp37-cp37m-manylinux2010_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 13.5MB/s eta 0:00:01
# Requirement already satisfied: lxml>=4.0 in /opt/anaconda3/lib/python3.7/site-packages (from pikepdf->img2pdf) (4.4.1)
# Building wheels for collected packages: img2pdf
#   Building wheel for img2pdf (setup.py) ... done
#   Created wheel for img2pdf: filename=img2pdf-0.4.0-cp37-none-any.whl size=40502 sha256=459277d7f7db7bbebd1edb5e721dd5972a26ab26e58dbfe53d4ac667b5e5e181
#   Stored in directory: /home/Valentina/.cache/pip/wheels/90/f5/7f/b88a76bac33669118e7549f4856bbe975a3ad2e59280c59196
# Successfully built img2pdf
# Installing collected packages: pikepdf, img2pdf
#   WARNING: The script img2pdf is installed in '/home/Valentina/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed img2pdf-0.4.0 pikepdf-2.7.0

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from torch.utils.data import DataLoader
import torch

from scipy.ndimage import uniform_filter, convolve
from scipy.stats import levene

import moviepy.video.io.ImageSequenceClip

from sdo.datasets.sdo_dataset import SDO_Dataset
from sdo.datasets.virtual_telescope_sdo_dataset import VirtualTelescopeSDO_Dataset
from sdo.models.vt_models.vt_unet import VT_UnetGenerator
from sdo.metrics.covariance import time_covariance, cov_1d, neighbor_cov
from sdo.datasets.dates_selection import get_datetime

import sunpy.visualization.colormaps as cm

# %% [markdown]
# # Load the trained model for inference (it takes a couple of mins)

# %%
results_path = '/fdl_sdo_data/bucket/EXPERIMENT_RESULTS/VIRTUAL_TELESCOPE/vale_exp_20/'
model_path = results_path + '0600_vale_exp_20_model.pth'
model = VT_UnetGenerator(input_shape=[3, 512, 512])
state_dict = torch.load(model_path)
from collections import OrderedDict
new_state_dict = OrderedDict()
for k, v in state_dict.items():
    name = k.replace("module.", "") 
    new_state_dict[name] = v
model.load_state_dict(new_state_dict)
model.eval();

# %% [markdown]
# # Identify some events for the experiments

# %%
flares_path = '/home/Valentina//expanding-sdo-capabilities/rare_events/flares_modelling.csv'

# %%
flares_df = pd.read_csv(flares_path)
flares_df
# Out:
#    event_type event_coordsys      hpc_x     hpc_y       hgc_x  hgc_y  \
# 0          FL   UTC-HGS-TOPO   16.00068 -223.2180   34.493617    -20
# 1          FL   UTC-HGS-TOPO -470.18040  486.3882  165.035490     24
# 2          FL   UTC-HGS-TOPO    0.00000  -66.6528  -80.512570      0
# 3          FL   UTC-HGS-TOPO  328.35900 -229.1394   33.086730    -20
# 4          FL   UTC-HGS-TOPO    0.00000  -90.0402   28.028327      0
# ..        ...            ...        ...       ...         ...    ...
# 79         FL   UTC-HGS-TOPO -777.47400 -347.2902 -153.199290    -19
# 80         FL   UTC-HGS-TOPO    0.00000   97.0440 -100.616140      0
# 81         FL   UTC-HGS-TOPO  168.14460  862.2900   44.443398     56
# 82         FL   UTC-HGS-TOPO    0.00000  122.3886   91.988507      0
# 83         FL   UTC-HGS-TOPO    0.00000  115.1892   32.195137      0
#
#              start_time             end_time frm_name obs_observatory  \
# 0   2011-02-14T04:29:00  2011-02-14T05:09:00     SWPC            GOES
# 1   2011-03-01T02:30:00  2011-03-01T04:40:00     SWPC            GOES
# 2   2010-11-05T12:43:00  2010-11-05T14:06:00     SWPC            GOES
# 3   2011-02-15T19:30:00  2011-02-15T20:53:00     SWPC            GOES
# 4   2011-07-28T02:19:00  2011-07-28T02:29:00     SWPC            GOES
# ..                  ...                  ...      ...             ...
# 79  2010-11-06T15:27:00  2010-11-06T15:44:00     SWPC            GOES
# 80  2011-01-28T00:44:00  2011-01-28T01:10:00     SWPC            GOES
# 81  2011-02-14T17:20:00  2011-02-14T17:32:00     SWPC            GOES
# 82  2011-03-09T01:52:00  2011-03-09T02:07:00     SWPC            GOES
# 83  2011-02-14T06:51:00  2011-02-14T07:03:00     SWPC            GOES
#
#    obs_instrument                                        kb_archivid  \
# 0            GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 1            GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 2            GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 3            GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 4            GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# ..            ...                                                ...
# 79           GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 80           GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 81           GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 82           GOES  ivo://helio-informatics.org/FL_SECstandard_201...
# 83           GOES  ivo://helio-informatics.org/FL_SECstandard_201...
#
#                                     HER event summary
# 0   https://www.lmsal.com/hek/her?cmd=view-voevent...
# 1   https://www.lmsal.com/hek/her?cmd=view-voevent...
# 2   https://www.lmsal.com/hek/her?cmd=view-voevent...
# 3   https://www.lmsal.com/hek/her?cmd=view-voevent...
# 4   https://www.lmsal.com/hek/her?cmd=view-voevent...
# ..                                                ...
# 79  https://www.lmsal.com/hek/her?cmd=view-voevent...
# 80  https://www.lmsal.com/hek/her?cmd=view-voevent...
# 81  https://www.lmsal.com/hek/her?cmd=view-voevent...
# 82  https://www.lmsal.com/hek/her?cmd=view-voevent...
# 83  https://www.lmsal.com/hek/her?cmd=view-voevent...
#
# [84 rows x 13 columns]

# %%
# we select 3 episodes at different times and of different length
df_selection = flares_df.loc[[1, 6, 77]][['start_time', 'end_time']]
df_selection
# Out:
#              start_time             end_time
# 1   2011-03-01T02:30:00  2011-03-01T04:40:00
# 6   2011-06-16T10:13:00  2011-06-16T10:29:00
# 77  2011-04-22T16:56:00  2011-04-22T17:14:00

# %%
# convert in datetimes and add the buffer
df_selection['start_datetime'] =  df_selection['start_time'].apply(lambda x: get_datetime(x, 1, 30, add=False))
df_selection['end_datetime'] =  df_selection['end_time'].apply(lambda x: get_datetime(x, 1, 30, add=True))
df_selection
# Out:
#              start_time             end_time      start_datetime  \
# 1   2011-03-01T02:30:00  2011-03-01T04:40:00 2011-03-01 01:00:00
# 6   2011-06-16T10:13:00  2011-06-16T10:29:00 2011-06-16 08:43:00
# 77  2011-04-22T16:56:00  2011-04-22T17:14:00 2011-04-22 15:26:00
#
#           end_datetime
# 1  2011-03-01 06:10:00
# 6  2011-06-16 11:59:00
# 77 2011-04-22 18:44:00

# %%
str(df_selection.loc[1].start_datetime)
# Out:
# '2011-03-01 01:00:00'

# %% [markdown]
# # Load the data

# %%
event = 77
folder = '/home/Valentina/results/exp_flares/' + f'flare_{event}/'
datetime_range = [[str(df_selection.loc[event].start_datetime), str(df_selection.loc[event].end_datetime)]]
data = VirtualTelescopeSDO_Dataset(data_basedir='/fdl_sdo_data/SDOMLmm/fdl_sw/SDOMLmm', 
    data_inventory='/home/Valentina/inventory_1904.pkl', 
    instr=["AIA", "AIA", "AIA", "AIA"], 
    num_channels = 4,
    channels=["0094", "0193", "0171", "0211"],
    datetime_range = datetime_range,
    resolution=512,
    subsample=1,
    test=False,
    test_ratio=0.0,
    shuffle=False,
    normalization=0,
    scaling=True,
    apodize=False,
    holdout=False)
# Out:
# /home/Valentina/expanding-sdo-capabilities/src/sdo/datasets/dates_selection.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel_df['date'] = sel_df.apply(from_row_to_date, axis=1)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
# in the first event we have 43 timestamps, at a distance of 6 minutes, given the inference is a bit slow 
# we might need to reduce the frequency
len(data.timestamps)
# Out:
# 34

# %%
data.timestamps
# Out:
# [(2011, 4, 22, 15, 24),
#  (2011, 4, 22, 15, 30),
#  (2011, 4, 22, 15, 36),
#  (2011, 4, 22, 15, 42),
#  (2011, 4, 22, 15, 48),
#  (2011, 4, 22, 15, 54),
#  (2011, 4, 22, 16, 0),
#  (2011, 4, 22, 16, 6),
#  (2011, 4, 22, 16, 12),
#  (2011, 4, 22, 16, 18),
#  (2011, 4, 22, 16, 24),
#  (2011, 4, 22, 16, 30),
#  (2011, 4, 22, 16, 36),
#  (2011, 4, 22, 16, 42),
#  (2011, 4, 22, 16, 48),
#  (2011, 4, 22, 16, 54),
#  (2011, 4, 22, 17, 0),
#  (2011, 4, 22, 17, 6),
#  (2011, 4, 22, 17, 12),
#  (2011, 4, 22, 17, 18),
#  (2011, 4, 22, 17, 24),
#  (2011, 4, 22, 17, 30),
#  (2011, 4, 22, 17, 36),
#  (2011, 4, 22, 17, 42),
#  (2011, 4, 22, 17, 48),
#  (2011, 4, 22, 17, 54),
#  (2011, 4, 22, 18, 0),
#  (2011, 4, 22, 18, 6),
#  (2011, 4, 22, 18, 12),
#  (2011, 4, 22, 18, 18),
#  (2011, 4, 22, 18, 24),
#  (2011, 4, 22, 18, 30),
#  (2011, 4, 22, 18, 36),
#  (2011, 4, 22, 18, 42)]

# %% [markdown]
# # Run the inference for each timestamp

# %%
# we collect the data for the analysis
input_data = []
gt_img = []
timestamps = []
for idx, _ in enumerate(data.timestamps):
    input_data.append(data[idx][0])
    gt_img.append(data[idx][1])
    timestamps.append(data[idx][2])

# %%
# compute the virtual image for each timestamp (this will take several minutes)
outputs = []
filename = '/home/Valentina/results/exp_flares/' + f'flares_{event}_outputs.rt'
if os.path.isfile(filename):
    outputs = torch.load(filename)
    if len(outputs)!=len(data.timestamps):
        print("Error, lenght of the saved files doesn't match")
else:
    for idx, _ in enumerate(data.timestamps):
        print(data[idx][2])
        outputs.append(
            model(data[idx][0].unsqueeze(0)).detach().numpy().reshape(1, 512, 512)
        )
    filename = '/home/Valentina/results/exp_flares/' + f'flares_{event}_outputs.rt'
    torch.save(outputs, filename)

# %% [markdown]
# # Looking at difference in covariance at interval of 6mins

# %%
results_cov = pd.DataFrame()
results = pd.DataFrame()
orig_channel = '211'
for i, _ in enumerate(data.timestamps):
    ts = '-'.join([str(i.item()) for i in timestamps[i]])
    X_s = outputs[i].reshape(512, 512)
    X_orig = gt_img[i].detach().numpy().reshape(512, 512)
    for j, ch in enumerate(["094", "193", "171"]):
        cov_orig, cov_synth = 0, 0
        Y = input_data[i][j].detach().numpy().reshape(512, 512)
        cov_orig = cov_1d(X_orig,Y)
        cov_synth = cov_1d(X_s,Y)
        flux = input_data[i][j].detach().numpy().sum()
        flux_orig = X_orig.sum()
        diff_orig = (X_s - X_orig).sum()
        percent_diff_orig = (X_s - X_orig).sum()*100/X_orig.sum()
        results_cov = results_cov.append(
            pd.DataFrame(index=[i], data={'Timestamp': ts, 'Channel': ch, 
                                'Flux': flux,
                               'True Cov': cov_orig, 'Pred Cov': cov_synth, 
                               'Diff': (cov_orig - cov_synth), 
                               '%Diff': (cov_orig - cov_synth)*100/cov_orig})
        )
    results = results.append(pd.DataFrame(index=[i], data={'Timestamp': ts, 'Channel': orig_channel,
                                                               'Flux': flux_orig, 
                                                               'Diff': diff_orig,
                                                               '%Diff': percent_diff_orig}
                                             ))

# %%
results_cov.reset_index().drop('index', axis=1).style.background_gradient(cmap='YlOrRd')
# Out:
# <style  type="text/css" >
#     #T_686d82c0_7a11_11eb_b08d_0baf983b7571row0_col2 {
#             background-color:  #fd8038;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row0_col3 {
#             background-color:  #ffe691;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row0_col4 {
#             background-color:  #fff2ac;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row0_col5 {
#             background-color:  #d9131f;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row0_col6 {
#             background-color:  #e31a1c;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row1_col2 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row1_col3 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row1_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row1_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row1_col6 {
#             background-color:  #e6211e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row2_col2 {
#             background-color:  #fd9f44;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row2_col3 {
#             background-color:  #fff2ac;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row2_col4 {
#             background-color:  #fff8bb;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row2_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row2_col6 {
#             background-color:  #e6211e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row3_col2 {
#             background-color:  #fd7c37;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row3_col3 {
#             background-color:  #ffe895;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row3_col4 {
#             background-color:  #fff3ae;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row3_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row3_col6 {
#             background-color:  #e51e1d;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row4_col2 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row4_col3 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row4_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row4_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row4_col6 {
#             background-color:  #e6211e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row5_col2 {
#             background-color:  #fd9f44;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row5_col3 {
#             background-color:  #fff3ae;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row5_col4 {
#             background-color:  #fff8bb;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row5_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row5_col6 {
#             background-color:  #e6211e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row6_col2 {
#             background-color:  #fd7a37;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row6_col3 {
#             background-color:  #ffe998;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row6_col4 {
#             background-color:  #fff4b0;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row6_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row6_col6 {
#             background-color:  #e41c1d;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row7_col2 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row7_col3 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row7_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row7_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row7_col6 {
#             background-color:  #e61f1d;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row8_col2 {
#             background-color:  #fd9f44;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row8_col3 {
#             background-color:  #fff3ae;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row8_col4 {
#             background-color:  #fff8bb;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row8_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row8_col6 {
#             background-color:  #e6211e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row9_col2 {
#             background-color:  #fd7836;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row9_col3 {
#             background-color:  #ffe997;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row9_col4 {
#             background-color:  #fff3af;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row9_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row9_col6 {
#             background-color:  #e41c1d;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row10_col2 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row10_col3 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row10_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row10_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row10_col6 {
#             background-color:  #e61f1d;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row11_col2 {
#             background-color:  #fd9f44;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row11_col3 {
#             background-color:  #fff3ae;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row11_col4 {
#             background-color:  #fff8bb;
#             color:  #000000;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row11_col5 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_686d82c0_7a11_11eb_b08d_0baf983b7571row11_col6 {
#             background-color:  #e61f1d;
#             color:  #f

# %% [markdown]
# * As expected results are very different for 193/171 and 094, being in general much worse for 094
# * Difference between real and predicted covariance >1h before the flare is 4%, but can arrive up to 20% in 094
# * After and close to the flare the predicted covariance is completely off and systematically larger

# %%
results.style.background_gradient(cmap='YlOrRd')
# Out:
# <style  type="text/css" >
#     #T_68777afa_7a11_11eb_b08d_0baf983b7571row0_col2 {
#             background-color:  #fff5b3;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row0_col3 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row0_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row1_col2 {
#             background-color:  #fffcc4;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row1_col3 {
#             background-color:  #fff0a7;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row1_col4 {
#             background-color:  #ffefa5;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row2_col2 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row2_col3 {
#             background-color:  #ffeb9c;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row2_col4 {
#             background-color:  #ffea9b;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row3_col2 {
#             background-color:  #fffac0;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row3_col3 {
#             background-color:  #fffcc4;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row3_col4 {
#             background-color:  #fffcc4;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row4_col2 {
#             background-color:  #fffac0;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row4_col3 {
#             background-color:  #fff4b0;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row4_col4 {
#             background-color:  #fff3af;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row5_col2 {
#             background-color:  #feb54f;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row5_col3 {
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row5_col4 {
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row6_col2 {
#             background-color:  #feac49;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row6_col3 {
#             background-color:  #c50624;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row6_col4 {
#             background-color:  #c50624;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row7_col2 {
#             background-color:  #febb56;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row7_col3 {
#             background-color:  #b40026;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row7_col4 {
#             background-color:  #b40026;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row8_col2 {
#             background-color:  #feb953;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row8_col3 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row8_col4 {
#             background-color:  #da141e;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row9_col2 {
#             background-color:  #fec863;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row9_col3 {
#             background-color:  #ed3022;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row9_col4 {
#             background-color:  #ed3022;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row10_col2 {
#             background-color:  #febf5a;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row10_col3 {
#             background-color:  #f33b25;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row10_col4 {
#             background-color:  #f33b25;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row11_col2 {
#             background-color:  #fd9e43;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row11_col3 {
#             background-color:  #fb4b29;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row11_col4 {
#             background-color:  #fc4f2a;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row12_col2 {
#             background-color:  #fc6631;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row12_col3 {
#             background-color:  #fa4a29;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row12_col4 {
#             background-color:  #fc4f2a;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row13_col2 {
#             background-color:  #fd883b;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row13_col3 {
#             background-color:  #fc6631;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row13_col4 {
#             background-color:  #fc6a32;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row14_col2 {
#             background-color:  #fd883b;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row14_col3 {
#             background-color:  #fd7034;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row14_col4 {
#             background-color:  #fd7435;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row15_col2 {
#             background-color:  #fc6330;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row15_col3 {
#             background-color:  #fea848;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row15_col4 {
#             background-color:  #feac49;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row16_col2 {
#             background-color:  #e92720;
#             color:  #f1f1f1;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row16_col3 {
#             background-color:  #fea145;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row16_col4 {
#             background-color:  #fea647;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row17_col2 {
#             background-color:  #fb4b29;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row17_col3 {
#             background-color:  #fc572c;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row17_col4 {
#             background-color:  #fc5d2e;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row18_col2 {
#             background-color:  #fd903d;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row18_col3 {
#             background-color:  #fc4f2a;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row18_col4 {
#             background-color:  #fc532b;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row19_col2 {
#             background-color:  #fd9640;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row19_col3 {
#             background-color:  #fd7435;
#             color:  #000000;
#         }    #T_68777afa_7a11_11eb_b08d_0baf983b7571row19_col4 {
#             background-color:  #fd7836;

# %%
fig, axs = plt.subplots(3, 1)
for channel in ["094", "193", "171"]:
    tmp_results = results_cov[results_cov.Channel == channel]
    factor = tmp_results.Flux.min()
    tmp_results.Flux = tmp_results.Flux/factor
    tmp_results.plot(x='Timestamp', y='Flux', label=channel, figsize=(17, 10), ax=axs[0])
factor = results.Flux.min()
results.Flux = results.Flux/factor
results.plot(x='Timestamp', y='Flux', label='211', figsize=(17, 10), ax=axs[0])
axs[0].set_ylabel('Total Flux')
axs[0].set_title('Flux by Channel /normalized to the min')

results.plot(x='Timestamp', y= '%Diff', label='211', figsize=(17, 10), ax=axs[1])
axs[1].set_ylabel('Real-Synt Image')
axs[1].set_title('Reconstruction Error on Image')

for channel in ["094", "193", "171"]:
    results_cov[results_cov.Channel == channel].plot(x='Timestamp', y= '%Diff', label=channel, 
                                                     figsize=(17, 10), ax=axs[2])
axs[2].set_ylabel('Real-Synt Cov')
axs[2].set_title('Reconstruction Error on Covariance')
fig.tight_layout()
filename = folder + 'Errors_vs_timestamps.png'
plt.savefig(filename, bbox_inches='tight')

# %% [markdown]
# # Comparing maps using a Neighborhood covariance with rolling average window

# %%
# compute covariance with real and synthetic image
for i, _ in enumerate(data.timestamps):
    fig, axs = plt.subplots(1,5, figsize=(15, 10))
    print(timestamps[i])
    X_s = outputs[i].reshape(512, 512)
    X_orig = gt_img[i].detach().numpy().reshape(512, 512)
    im = axs[0].set_title(f'AIA 211 GT')
    cmap=plt.get_cmap('sdoaia211')
    im = axs[0].imshow(X_orig, origin='lower', cmap=cmap, vmin=-0.8, vmax=0.8)
    im = axs[1].set_title(f'AIA 211 PR - GT')
    im = axs[1].imshow((X_s - X_orig), cmap='seismic', origin='lower', vmin=-0.8, vmax=0.8)
    for j, ch in enumerate(["094", "193", "171"]):    
        Y = input_data[i][j].detach().numpy().reshape(512,512)
        cov_synth = neighbor_cov(X_s, Y, size=20)
        cov_orig = neighbor_cov(X_orig, Y, size=20)
        im = axs[j+2].set_title(f'Cov AIA {ch}-{211} PR - GT')
        im = axs[j+2].imshow((cov_synth - cov_orig), cmap='seismic', origin='lower', vmin=-0.8, vmax=0.8)
        fig.subplots_adjust(bottom=0.1, right=0.8, top=0.8)
        cbar_ax = fig.add_axes([0.85, 0.3, 0.03, 0.3])
        fig.colorbar(im, cax=cbar_ax)
    plt.show()
# Out:
# tensor([2011,    4,   22,   15,   24])
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# tensor([2011,    4,   22,   15,   30])
# tensor([2011,    4,   22,   15,   36])
# tensor([2011,    4,   22,   15,   42])
# tensor([2011,    4,   22,   15,   48])
# tensor([2011,    4,   22,   15,   54])
# tensor([2011,    4,   22,   16,    0])
# tensor([2011,    4,   22,   16,    6])
# tensor([2011,    4,   22,   16,   12])
# tensor([2011,    4,   22,   16,   18])
# tensor([2011,    4,   22,   16,   24])
# tensor([2011,    4,   22,   16,   30])
# tensor([2011,    4,   22,   16,   36])
# tensor([2011,    4,   22,   16,   42])
# tensor([2011,    4,   22,   16,   48])
# tensor([2011,    4,   22,   16,   54])
# tensor([2011,    4,   22,   17,    0])
# tensor([2011,    4,   22,   17,    6])
# tensor([2011,    4,   22,   17,   12])
# tensor([2011,    4,   22,   17,   18])
# tensor([2011,    4,   22,   17,   24])
# tensor([2011,    4,   22,   17,   30])
# tensor([2011,    4,   22,   17,   36])
# tensor([2011,    4,   22,   17,   42])
# tensor([2011,    4,   22,   17,   48])
# tensor([2011,    4,   22,   17,   54])
# tensor([2011,    4,   22,   18,    0])
# tensor([2011,    4,   22,   18,    6])
# tensor([2011,    4,   22,   18,   12])
# tensor([2011,    4,   22,   18,   18])
# tensor([2011,    4,   22,   18,   24])
# tensor([2011,    4,   22,   18,   30])
# tensor([2011,    4,   22,   18,   36])
# tensor([2011,    4,   22,   18,   42])

# %% [markdown]
# as suggested by the aggregated covariance on the full image, results before and after the flare are much worse,
# particulalry the 094-211 pair. We can however see the error is localised

# %% [markdown]
# # Create video

# %%
# compute covariance with real and synthetic image
video_folder = folder + 'video/'
if not os.path.exists(video_folder):
    os.makedirs(video_folder)
fig_format = '.png'
cmap=plt.get_cmap('sdoaia211')

for i, timestamp in enumerate(data.timestamps):
    fig, axs = plt.subplots(1,2, figsize=(15, 10))
    filename = video_folder + '_'.join([str(number) for number in timestamp]) + fig_format
    X_s = outputs[i].reshape(512, 512)
    X_orig = gt_img[i].detach().numpy().reshape(512, 512)
    im = axs[0].set_title(f'{timestamp} AIA 211 GT')
    im = axs[0].imshow(X_orig, origin='lower', cmap=cmap)
    #im = axs[1].set_title(f'AIA 211 PR - GT')
    #im = axs[1].imshow((X_s - X_orig), cmap='seismic', origin='lower', vmin=-0.8, vmax=0.8)
    for j, ch in enumerate(["094"]):    
        Y = input_data[i][j].detach().numpy().reshape(512,512)
        cov_synth = neighbor_cov(X_s, Y, size=10)
        cov_orig = neighbor_cov(X_orig, Y, size=10)
        im = axs[j+1].set_title(f'Cov AIA {ch}-{211} PR - GT')
        im = axs[j+1].imshow((cov_synth - cov_orig), cmap='seismic', origin='lower', vmin=-0.8, vmax=0.8)
        fig.subplots_adjust(bottom=0.1, right=0.8, top=0.8)
        cbar_ax = fig.add_axes([0.85, 0.3, 0.03, 0.3])
        fig.colorbar(im, cax=cbar_ax)
    # plt.show()
    plt.savefig(filename, bbox_inches='tight')
    plt.close()

# %%
video_name = folder + f'flare_{event}.mp4'
image_files = [folder+'/'+ img for img in os.listdir(folder) if img.endswith(".png")]
image_files.sort()
clip = moviepy.video.io.ImageSequenceClip.ImageSequenceClip(image_files, fps=2)
clip.write_videofile(video_name)
# Out:
# t:  24%|██▎       | 8/34 [00:00<00:00, 68.86it/s, now=None]
# Moviepy - Building video /home/Valentina/results/exp_flares/flare_77/flare_77.mp4.
# Moviepy - Writing video /home/Valentina/results/exp_flares/flare_77/flare_77.mp4
# Moviepy - Done !
# Moviepy - video ready /home/Valentina/results/exp_flares/flare_77/flare_77.mp4

# %%
from IPython.display import Video
Video(video_name)
# Out:
# <video src="/home/Valentina/results/exp_flares/flare_77/flare_77.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
